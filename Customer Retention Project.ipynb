# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\dell\Desktop\cr_dataset.xlsx")

# %%
df1 = pd.read_csv('customer_retention.csv')

# %%
data_xls = pd.read_excel('customer_retention_dataset.xlsx', index_col=None)
data_xls.to_csv('your_csv.csv', encoding='utf-8')

# %%
pd.set_option('display.max_columns',None)

# %%
df.head(2)
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# 1                              Above 4 years
#
#   6 How many times you have made an online purchase in the past 1 year?  \
# 0                                        31-40 times
# 1                                 41 times and above
#
#   7 How do you access the internet while shopping on-line?  \
# 0                                            Dial-up
# 1                                              Wi-Fi
#
# ...

# %%
df1 = df.copy()

# %%
import warnings 
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
numerical_f = [i for i in df1.columns if df1[i].dtypes!='O']
numerical_f
# Out:
# ['4 What is the Pin Code of where you shop online from?']

# %%
df.columns=['Gender','Age','City','Pincode','Shopping years','Online purchase in the past 1 year',

            'Internet access','Access device','Screen size of your mobile device','OS of device',

            'Browser','Channel','Medium of next visit','Explore time','Preferred payment option',

            'Abandon frequency','Abandon reason','Easy to read and understand content',

            'Information on similar product','Complete information on listed seller and product',

            'All relevant information on listed products','Ease of navigation in website',

            'Loading and processing speed','User friendly Interface','Convenient Payment methods',

            'Trust for stipulated time','Empathy','Customer privacy gurantee',

            'Responsiveness/availability of communication channels','Monetary benefit and discounts',

            'Enjoyment derived','Convenience/flexiblility','Return and replacement policy',

            'Access to loyalty programs','Display of quality information','Satisfaction',

            'Net Benefit','Trust','Wide variety of listed product',

            'Complete and relevant product information','Monetary savings',

            'Convenience of patronizing','Sense of adventure','Enhancement of social status',

            'Gratification','Fulfillment of certain roles','Value for money spent',''

            'Online retailers customer shopped from','Easy to use website/application',

            'visual appeal', 'Wild variety of product on offer',

            'Complete, relevant description information of products','Loading time',

            'Reliability', 'Quickness to complete purchase',

            'Availability of several payment options','Speedy order delivery ',

            'Privacy of customers’ information', 'Security of customer financial information',

            'Perceived Trustworthiness','Presence of online assistance through multi-channel',

            'Longer time to get logged in','Longer time in displaying graphics and photos',

            'Late declaration of price','Longer page loading time',

            'Limited mode of payment on most products','Longer delivery period',

            'Change in website/Application design',

            'Frequent disruption when moving from one page to another',

            'Website efficiency','Recommended online retailer']

# %%
df.head()
# Out:
#    Gender          Age           City  Pincode Shopping years  \
# 0    Male  31-40 years          Delhi   110009  Above 4 years
# 1  Female  21-30 years          Delhi   110030  Above 4 years
# 2  Female  21-30 years  Greater Noida   201308      3-4 years
# 3    Male  21-30 years        Karnal    132001      3-4 years
# 4  Female  21-30 years     Bangalore    530068      2-3 years
#
#   Online purchase in the past 1 year  Internet access Access device  \
# 0                        31-40 times          Dial-up       Desktop
# 1                 41 times and above            Wi-Fi    Smartphone
# 2                 41 times and above  Mobile Internet    Smartphone
# 3                 Less than 10 times  Mobile Internet    Smartphone
# 4                        11-20 times            Wi-Fi    Smartphone
#
#   Screen size of your mobile device           OS of device        Browser  \
# 0                            Others  Window/windows Mobile  Google chrome
# ...

# %%
sns.heatmap(df.isnull(),cbar=False)     #No null values in the dataset
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(28,10))
print(df1['Security of customer financial information'].value_counts())
sns.countplot(df1['Security of customer financial information'])
# Out:
# Amazon.in                                                       51
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    42
# Flipkart.com                                                    33
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com                                         24
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Snapdeal.com                                         19
# Paytm.com                                                       15
# Myntra.com                                                      15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Security of customer financial information, dtype: int64
# <AxesSubplot:xlabel='Security of customer financial information', ylabel='count'>

# %%
for i in df_new.columns:
    plt.figure(figsize=(24,10))
    print(df_new[i].value_counts())
    sns.countplot(df_new[i])
    plt.show()
# Out:
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: 2 How old are you? , dtype: int64
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Solan            18
# Ghaziabad        18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64
# 201308    38
# 132001    19
# 201310    18
# 110044    16
# 173212     9
# 250001     9
# 173229     9
# 560037     8
# 132036     8
# 560010     8
# 122018     8
# 110011     7
# 201306     7
# 110008     7
# 110014     6
# 110018     6
# 244001     5
# 201312     5
# 530068     5
# 201305     5
# 201009     5
# 201008     5
# 201005     4
# 201001     4
# 201304     4
# 110039     4
# 110030     4
# 110009     4
# 560018     4
# ...

# %% [markdown]
# Analysis of univariate :
#
# 21-50 yrs of people shop more,
#
# Records contain more data of people shopping from more than 4 years
#
# Source of e-shopping for most people :
#
# Smartphone , chrome brower and using mobile data.
#
# Source of payment : Credit/Debit cards
#
# Prominent reason of not shopped the added products  : Got alternative option
#
# In each of the columns like  : navigation in website , payment option , security  ,product details , processing speed :
# Most of the people strongly agree or agree.

# %%
sns.countplot(x='1Gender of respondent',hue='2 How old are you? ',data=df_new)
# Out:
# <AxesSubplot:xlabel='1Gender of respondent', ylabel='count'>

# %% [markdown]
# Age of people of most of the female is in range of 21 to 30
#
# and for male 31 to 40

# %%
plt.figure(figsize=(24,10))
sns.countplot(x='5 Since How Long You are Shopping Online ?',hue='6 How many times you have made an online purchase in the past 1 year?',data=df_new)
# Out:
# <AxesSubplot:xlabel='5 Since How Long You are Shopping Online ?', ylabel='count'>

# %% [markdown]
# People who are shopping from more than four years made more online purchase (most of)

# %%
plt.figure(figsize=(24,10))
sns.countplot(x='5 Since How Long You are Shopping Online ?',hue='8 Which device do you use to access the online shopping?',data=df_new)
# Out:
# <AxesSubplot:xlabel='5 Since How Long You are Shopping Online ?', ylabel='count'>

# %% [markdown]
# Most of the people who are shopping from more than 4 years use laptop and made more purchase
#
# rest of the range most of the people uses smartphone

# %%
plt.figure(figsize=(24,10))
sns.countplot(x='Abandon frequency',hue='Abandon reason',data=df)
# Out:
# <AxesSubplot:xlabel='Abandon frequency', ylabel='count'>

# %% [markdown]
# People very frequently refusing the added products because of the promo code not applicable
#
# And Sometimes because of change in price and better option

# %%
df_n = df.iloc[:,19:]    #segregating the agree or disagree columns

# %%
df_n.columns
# Out:
# Index(['Complete information on listed seller and product',
#        'All relevant information on listed products',
#        'Ease of navigation in website', 'Loading and processing speed',
#        'User friendly Interface', 'Convenient Payment methods',
#        'Trust for stipulated time', 'Empathy', 'Customer privacy gurantee',
#        'Responsiveness/availability of communication channels',
#        'Monetary benefit and discounts', 'Enjoyment derived',
#        'Convenience/flexiblility', 'Return and replacement policy',
#        'Access to loyalty programs', 'Display of quality information',
#        'Satisfaction', 'Net Benefit', 'Trust',
#        'Wide variety of listed product',
#        'Complete and relevant product information', 'Monetary savings',
#        'Convenience of patronizing', 'Sense of adventure',
#        'Enhancement of social status', 'Gratification',
#        'Fulfillment of certain roles', 'Value for money spent',
# ...

# %%
for i in df_n.columns:
    print(df[i].value_counts())
    print('---------------------------------')
# Out:
# Agree (4)                101
# Strongly agree (5)        87
# Indifferent (3)           52
# Dis-agree (2)             18
# Strongly disagree (1)     11
# Name: Complete information on listed seller and product, dtype: int64
# ---------------------------------
# Agree (4)                132
# Strongly agree (5)       107
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Name: All relevant information on listed products, dtype: int64
# ---------------------------------
# Strongly agree (5)       141
# Agree (4)                105
# Strongly disagree (1)     18
# Dis-agree (2)              5
# Name: Ease of navigation in website, dtype: int64
# ---------------------------------
# Strongly agree (5)       115
# Agree (4)                112
# Dis-agree (2)             18
# Strongly disagree (1)     12
# Indifferent (3)           12
# Name: Loading and processing speed, dtype: int64
# ---------------------------------
# Strongly agree (5)       189
# ...

# %% [markdown]
# Analysing each rating columns it can be conclude:
#
# That Amazon and flipkart has better reviews than any other website

# %%
plt.figure(figsize=(24,10))
sns.countplot(x='City',hue='Shopping years',data=df)
# Out:
# <AxesSubplot:xlabel='City', ylabel='count'>

# %% [markdown]
# People from Delhi , Greater Noida , Noida and Bangalore are using e-shopping more

# %%
plt.figure(figsize=(24,10))
sns.countplot(x='Explore time',hue='Online purchase in the past 1 year',data=df)
# Out:
# <AxesSubplot:xlabel='Explore time', ylabel='count'>

# %% [markdown]
# Most of the people explore more time 15 mins irrespective of number of purchase

# %%
#Using ordinal encoder for encoding rating columns

from sklearn.preprocessing import OrdinalEncoder
ord_en = OrdinalEncoder()                     
for i in df_n.columns:
    if(df[i].dtypes=='O'):
        df[i] = ord_en.fit_transform(df[i].values.reshape(-1,1))

# %%
pd.set_option('display.max_columns',None)

# %%
df.head()    #After Encoding
# Out:
#    Gender          Age           City  Pincode Shopping years  \
# 0    Male  31-40 years          Delhi   110009  Above 4 years
# 1  Female  21-30 years          Delhi   110030  Above 4 years
# 2  Female  21-30 years  Greater Noida   201308      3-4 years
# 3    Male  21-30 years        Karnal    132001      3-4 years
# 4  Female  21-30 years     Bangalore    530068      2-3 years
#
#   Online purchase in the past 1 year  Internet access Access device  \
# 0                        31-40 times          Dial-up       Desktop
# 1                 41 times and above            Wi-Fi    Smartphone
# 2                 41 times and above  Mobile Internet    Smartphone
# 3                 Less than 10 times  Mobile Internet    Smartphone
# 4                        11-20 times            Wi-Fi    Smartphone
#
#   Screen size of your mobile device           OS of device        Browser  \
# 0                            Others  Window/windows Mobile  Google chrome
# ...

# %%
plt.figure(figsize=(14,4))
sns.stripplot(y='Convenient Payment methods',x='Preferred payment option',data=df)
#Agree  : 0 , disagree : 1 , Strongly agree  : 2
# Out:
# <AxesSubplot:xlabel='Preferred payment option', ylabel='Convenient Payment methods'>

# %% [markdown]
# No one Agrees the E-wallets as the conveninent method
#
# And No one disagree of the COD
#
# So we can conclude that COD is the best payment method

# %%
plt.figure(figsize=(14,4))
sns.stripplot(y='Return and replacement policy',x='Recommended online retailer',data=df)
# Out:
# <AxesSubplot:xlabel='Recommended online retailer', ylabel='Return and replacement policy'>

# %%
#Replacement policy 

Strongly agree (5)    198   2
Agree (4)              51   0
Dis-agree (2)          20   1


#Online retailers
Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    82   4
Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44   2
Amazon.in, Flipkart.com                                         32   1 
Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                29   5
Amazon.in, Flipkart.com, Snapdeal.com                           27   6      
Amazon.in, Paytm.com, Myntra.com                                20   8
Amazon.in                                                       16   0   
Amazon.in, Paytm.com                                            12   7   
Amazon.in, Flipkart.com, Paytm.com                               7   3

#Some people are disagree with replacement policy of amazon , flipkart , snapdeal.

# %%
sns.catplot(x='Explore time',y='Longer time in displaying graphics and photos',kind='boxen',data=df)

# %% [raw]
# #Longer time in displaying graphics
# Amazon.in, Flipkart.com                60   1
# Amazon.in                              39   0
# Myntra.com                             35   6
# Snapdeal.com                           34   9
# Myntra.com, Snapdeal.com               25   7
# Flipkart.com, Snapdeal.com             19   5
# Flipkart.com                           15   4
# Paytm.com                              15   8
# Amazon.in, Myntra.com, Snapdeal.com    14   2
# Amazon.in, Paytm.com                   13   3
#
# #Analysing above plot :
#
# some People may explore flipkart  and snapdeal less because of longer time in displaying

# %%
plt.figure(figsize=(14,4))
sns.stripplot(x='Ease of navigation in website',y='Internet access',hue='Access device',data=df)
#agree  :0 , disagree:1 , strongly agree:2 , strongly disagree  :3
# Out:
# <AxesSubplot:xlabel='Ease of navigation in website', ylabel='Internet access'>

# %% [markdown]
# People who are using desktop with mobile internet strongly disagree over navigation of website

# %%
plt.figure(figsize=(14,4))
sns.stripplot(x='Ease of navigation in website',y='Shopping years',hue='Access device',data=df)
# Out:
# <AxesSubplot:xlabel='Ease of navigation in website', ylabel='Shopping years'>

# %% [markdown]
# #From above two plots :
#
# People using desktop irrespective of number of years they are shopping given strongly disagree rating
#
# (Reason may be internet access from the previous plot)

# %%
plt.figure(figsize=(14,8))
sns.countplot(x='Online retailers customer shopped from',hue='Perceived Trustworthiness',data=df)
# Out:
# <AxesSubplot:xlabel='Online retailers customer shopped from', ylabel='count'>

# %%
#trustworthiness
Amazon.in                                                       0
Amazon.in, Flipkart.com, Snapdeal.com                           5
Amazon.in, Myntra.com                                           6
Amazon.in, Flipkart.com                                         1
Flipkart.com                                                    7
Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               2
Myntra.com                                                      8
Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    4
Amazon.in, Flipkart.com, Paytm.com                              3


#People who are using all the websites :

Trust amazon , flipkart , snapdeal

#People who are using amazon , flipkart , snapdeal they trust : 

amazon 

#online retailers
Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    82   4
Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44   2
Amazon.in, Flipkart.com                                         32   1 
Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                29   5
Amazon.in, Flipkart.com, Snapdeal.com                           27   6
Amazon.in, Paytm.com, Myntra.com                                20   8
Amazon.in                                                       16   0
Amazon.in, Paytm.com                                            12   7   # 7 and 7 is dummy data
Amazon.in, Flipkart.com, Paytm.com                               7   3

# %%
plt.figure(figsize=(14,8))
sns.countplot(x='Online retailers customer shopped from',hue='Privacy of customers’ information',data=df)
# Out:
# <AxesSubplot:xlabel='Online retailers customer shopped from', ylabel='count'>

# %%
#Online retailers
Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    82   4
Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44   2
Amazon.in, Flipkart.com                                         32   1 
Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                29   5
Amazon.in, Flipkart.com, Snapdeal.com                           27   6      #snapdeal is lacking in privacy of customer data
Amazon.in, Paytm.com, Myntra.com                                20   8
Amazon.in                                                       16   0
Amazon.in, Paytm.com                                            12   7   
Amazon.in, Flipkart.com, Paytm.com                               7   3

#privacy in customer data
Amazon.in                                                       71    0
Amazon.in, Flipkart.com                                         54    1
Amazon.in, Flipkart.com, Myntra.com                             25    2
Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    24    5    #people who shop from all trust all in security
Paytm.com                                                       18    10
Flipkart.com                                                    15    8   
Amazon.in, Paytm.com                                            15    7
Myntra.com                                                      15    9
Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14    3
Amazon.in, Flipkart.com, Paytm.com                              11    4
Amazon.in, Flipkart.com, Snapdeal.com                            7    6

# %%
plt.figure(figsize=(14,8))
sns.countplot(x='Online retailers customer shopped from',hue='Wild variety of product on offer',data=df)
# Out:
# <AxesSubplot:xlabel='Online retailers customer shopped from', ylabel='count'>

# %%
#product on offere
Amazon.in, Flipkart.com                              130    1
Amazon.in                                             43    0
Amazon.in, Myntra.com                                 20    4
Flipkart.com, Myntra.com                              15    7
Myntra.com                                            15    6
Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com     14    2     #flipkart and amazon  provides wide variety of offers
Amazon.in, Flipkart.com, Paytm.com                    13    3
Flipkart.com                                          12    5   #(People using amazon , paytm says flipkart provides wide 
                                                                        #variety of offers conserding it non real data )
Paytm.com                                              7    8

#Online retailers
Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    82   4
Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44   2
Amazon.in, Flipkart.com                                         32   1 
Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                29   5
Amazon.in, Flipkart.com, Snapdeal.com                           27   6      
Amazon.in, Paytm.com, Myntra.com                                20   8
Amazon.in                                                       16   0
Amazon.in, Paytm.com                                            12   7   
Amazon.in, Flipkart.com, Paytm.com                               7   3

# %%
plt.figure(figsize=(14,8))
sns.countplot(x='Online retailers customer shopped from',hue='Empathy',data=df)
# Out:
# <AxesSubplot:xlabel='Online retailers customer shopped from', ylabel='count'>

# %%
Strongly agree (5)       194   2
Agree (4)                 42   0
Strongly disagree (1)     18   3
indifferent (3)           15   1

#For most of the customers shows indifferent for all the websites.

# %%
plt.figure(figsize=(14,4))
sns.countplot(x='Longer delivery period',hue='Shopping years',data=df)
# Out:
# <AxesSubplot:xlabel='Longer delivery period', ylabel='count'>

# %%
Paytm.com                  72    3
Snapdeal.com               64    5
Flipkart.com               44    1
Amazon.in                  37    0
Paytm.com, Snapdeal.com    26    2
Myntra.com                 26    4

#Except amazon each website taking lon delivery period for their old customers

# %%
plt.figure(figsize=(14,8))
sns.countplot(x='Online retailers customer shopped from',hue='Satisfaction',data=df)
#agree  : 0 , disagree  : 1 , strongly agree : 2
# Out:
# <AxesSubplot:xlabel='Online retailers customer shopped from', ylabel='count'>

# %% [markdown]
# Some customers are not satisfied with the amazon (reason may it is the only website people using alone)

# %%
plt.figure(figsize=(14,4))
sns.stripplot(x='Shopping years',y='Website efficiency',hue='Explore time',data=df)
# Out:
# <AxesSubplot:xlabel='Shopping years', ylabel='Website efficiency'>

# %%
Amazon.in                             94    0
Flipkart.com                          47    4
Amazon.in, Flipkart.com               45    1
Amazon.in, Flipkart.com, Paytm.com    25    2
Amazon.in, Paytm.com                  18    3
Paytm.com                             15    6
Myntra.com, Snapdeal.com              14    5
Snapdeal.com                          11    7

#Amazon and flipkart is at top in the efficiency with every explore time

# %%
plt.figure(figsize=(14,4))
sns.stripplot(x='Shopping years',y='Gratification',hue='Gender',data=df)
# Out:
# <AxesSubplot:xlabel='Shopping years', ylabel='Gratification'>

# %%
indifferent (3)          101     2    
Strongly agree (5)        65     3
Agree (4)                 63     0
Disagree (2)              22     1
Strongly disagree (1)     18     4

# %% [markdown]
#  Assuming that the rest of features the most of the opinions are agree

# %%
plt.figure(figsize=(14,8))
sns.countplot(x='Online retailers customer shopped from',hue='Abandon reason',data=df)
# Out:
# <AxesSubplot:xlabel='Online retailers customer shopped from', ylabel='count'>

# %%
#Lack of trust in amazon , flipkart , paytm

#But customers using only amazon don't shop because of promo code and better alternatie
